# %%
a=5
print(a//2)  #akairea diairesi
print(a%2)      #modulo
b=3
print(b/2*3)        #PRIORITY FROM LEFT TO RIGHT
print(b/(2*3))
c=10
print(c*9/5)
print(c*9/5*2)
print(c*9/(5*2))
b=2
print(b**8)
print(b**2**3)       #PRIORITY ?????????????
print((b**2)**3)
print(b**1.42)
print(b**2**0.5)
print(b**0.5**2)
# Out:
# 2
# 1
# 4.5
# 0.5
# 18.0
# 36.0
# 9.0
# 256
# 256
# 64
# 2.675855109572224
# 2.665144142690225
# 1.189207115002721
