# %%
sum = 0
count = 1
while count <= 100:
    sum += count
    count += 1
print("The sum is", sum)
# Out:
# The sum is 5050

# %%
total = 0
while total < 100:
    num = int(input('Enter a number: '))
    total = total + num
print("The total is", total)
# Out:
# Enter a number:  30
# Enter a number:  40
# Enter a number:  50
# The total is 120

# %%
again = 'yes'
while again == 'yes' :
    again = input("again  ??? ")
    print("Hello....")
# Out:
# again  ???  no
# Hello....

# %%
again = 'yes'
while again == 'yes' :
    
    again = input("again  ??? ")
    if again != 'yes' :
        break
# Out:
# again  ???  yes
# again  ???  no

# %%
f = 1
k = 1
while k <= 4 :
    print(k)
    f = f*k
    k +=1
print(f)
# Out:
# 1
# 2
# 3
# 4
# 24

# %%
num=5
factorial = 1
count = 1
while count <= num :
    factorial *= count
    count +=1
print("factorial of " , num , "is" , factorial)
# Out:
# factorial of  5 is 120

# %%
while True:
    response = input("Enter a command (quit to exit): ")
    if response == "quit":
        break
    print("You entered:", response)
# Out:
# Enter a command (quit to exit):  kiki
# You entered: kiki
# Enter a command (quit to exit):  koko
# You entered: koko

# %% [markdown]
# ### guess

# %%
guess = 50
count = 0
ans = 0
while ans != guess  : 
    ans = int(input("give a number btn 1 and 100"))
    if ans > guess : print("too high..."); count +=1
    elif ans < guess : print("too low..."); count +=1
    else : print("number found after " , count , "guesses!")
# Out:
# give a number btn 1 and 100 5
# too low...
# give a number btn 1 and 100 88
# too high...
# give a number btn 1 and 100 77
# too high...
# give a number btn 1 and 100 66
# too high...
# give a number btn 1 and 100 55
# too high...
# give a number btn 1 and 100 44
# too low...
# give a number btn 1 and 100 47
# too low...
# give a number btn 1 and 100 49
# too low...
# give a number btn 1 and 100 53
# too high...
# give a number btn 1 and 100 50
# number found after  9 guesses!

# %%
count = 0
while count < 10:
    count += 1
    if count % 2 == 0:
        continue
    print(count)
    if count >= 7:
        break
# Out:
# 1
# 3
# 5
# 7
