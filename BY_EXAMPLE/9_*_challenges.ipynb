# %% [markdown]
# ### 69   index : tuple.index(item)
# ### Create a tuple containing the names of five countries and display the whole tuple. Ask
# the user to enter one of the countries that have been shown to them and then display
# the index number (i.e. position in the list) of that item in the tuple.

# %%
countries = ('Greece' , 'Japan' , 'France' , 'Italia' , 'Spain')

# %%
country = input("select a country from the list... ")
# Out:
# select a country from the list...  Spain

# %%
print("selected country has index..." , countries.index(country))
# Out:
# selected country has index... 4

# %% [markdown]
# ### 70   Item from index  : tuple[index]
# ### Add to program 069 to ask the
# user to enter a number and
# display the country in that
# position.

# %%
indice = int(input("the index of a country.... "))
print("country with index... " , indice , 'is' , countries[indice])
# Out:
# the index of a country....  2
# country with index...  2 is France

# %% [markdown]
# ### 71
# ### Create a list of two sports. Ask the
# user what their favourite sport is and
# add this to the end of the list. Sort the
# list and display it.

# %%
sports = ['foot' , 'volley']
favorite = input(" what is your favorite sport ?... ")
sports.append(favorite)
sorted_sports = sorted(sports)
print(sorted_sports)
# Out:
#  what is your favorite sport ?...  climbing
# ['climbing', 'foot', 'volley']

# %% [markdown]
# ### 072
# Create a list of six school subjects. Ask the user which of these
# subjects they don’t like. Delete the subject they have chosen from the
# list before you display the list again.

# %%
classes = ["math" , "physics" , "chem" , "gym" , "lettres" , "grammar"]
desagreable = input("select course you don't like....")
get_rid = classes.index(desagreable)
del classes[get_rid]
print(classes)
# Out:
# select course you don't like.... gym
# ['math', 'physics', 'chem', 'lettres', 'grammar']

# %% [markdown]
# ### Python dictionary is a built-in data type that stores key-value pairs. Here are some of the most commonly used dictionary methods in Python:
#
# ### clear(): Removes all the elements from the dictionary.
# ### copy(): Returns a shallow copy of the dictionary.
# ### get(key[, default]): Returns the value for the specified key. If the key is not found, it returns the default value.
# ### items(): Returns a view object that contains the key-value pairs of the dictionary.
# ### keys(): Returns a view object that contains the keys of the dictionary.
# ### pop(key[, default]): Removes and returns the value for the specified key. If the key is not found, it returns the default value.
# ### popitem(): Removes and returns an arbitrary key-value pair from the dictionary.
# ### ### setdefault(key[, default]): Returns the value for the specified key. If the key is not found, it adds the key-value pair to the dictionary with the default value.
# ### update(other): Updates the dictionary with the key-value pairs from the specified dictionary or iterable.
# ### values(): Returns a view object that contains the values of the dictionary.
# ### Here is an example of how to use some of these methods:

# %%
# Create a dictionary
my_dict = {'a': 1, 'b': 2, 'c': 3}

# Use the get() method to get the value for a key
value = my_dict.get('a')
print(value)  # Output: 1

# Use the items() method to get the key-value pairs of the dictionary
items = my_dict.items()
print(items)  # Output: dict_items([('a', 1), ('b', 2), ('c', 3)])

# Use the pop() method to remove a key-value pair from the dictionary
my_dict.pop('a')
print(my_dict)  # Output: {'b': 2, 'c': 3}

# Use the update() method to update the dictionary with new key-value pairs
my_dict.update({'d': 4, 'e': 5})
print(my_dict)  # Output: {'b': 2, 'c': 3, 'd': 4, 'e': 5}
my_dict.get('c')  ## returns 3 ,from key=> value
# Out:
# 1
# dict_items([('a', 1), ('b', 2), ('c', 3)])
# {'b': 2, 'c': 3}
# {'b': 2, 'c': 3, 'd': 4, 'e': 5}
# 3

# %% [markdown]
# ### 073
# ### Ask the user to enter four of their favourite foods and store them in a dictionary so that they are indexed with
# ### numbers starting from 1. Display the dictionary in full, showing the index number and the item. Ask them which they want to get rid  f and remove it from the list. Sort the remaining data and display the dictionary.

# %%
menu = {}
food_1 = input('food_1')
food_2 = input('food_2')
food_3 = input('food_3')
food_4 = input("food_4")
menu.update({1 : food_1 , 2 : food_2 , 3 : food_3 , 4 : food_4})
menu.items()
print(menu)
dislike = int(input("food to remove...key... "))

menu.pop(dislike)
print(menu)
print(sorted(menu.values()))
# Out:
# food_1 toma
# food_2 pata
# food_3 egg
# food_4 rice
# {1: 'toma', 2: 'pata', 3: 'egg', 4: 'rice'}
# food to remove...key...  2
# {1: 'toma', 3: 'egg', 4: 'rice'}
# ['egg', 'rice', 'toma']
