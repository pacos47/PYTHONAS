# %% [markdown]
# In Python, the if __name__ == "__main__": statement is used to ensure that certain code only runs when the script is executed directly, not when it's imported as a module.

# %%
def main():
    print("Hello from main!")

if __name__ == "__main__":
    main()
# Out:
# Hello from main!

# %% [markdown]
# Explanation:
#
# __name__ is a special built-in variable in Python.
#
# When a file is run directly, __name__ is set to "__main__".
#
# When the file is imported as a module in another script, __name__ is set to the module's name.
#
# In Python, __name__ is called a special built-in variable because:
#
# It is automatically defined by Python.
#
# It has special meaning depending on how the script is run.
#
# It uses double underscores before and after (this is often called a "dunder" name, short for Double UNDERscore).

# %%
def greet():
    print("Hello from the greet() function!")

# This block only runs if the script is executed directly
if __name__ == "__main__":
    greet()
# Out:
# Hello from the greet() function!

# %% [markdown]
# What it does:
# If you run this script directly (e.g., python myscript.py), it will print:
# Hello from the greet() function!
#
# If you import it into another script (e.g., import myscript), nothing will print automatically.

# %%
def greet():
    print("Hello from greet() in hello.py!")

if __name__ == "__main__":
    greet()
# Out:
# Hello from greet() in hello.py!

# %% [markdown]
# #### test_import  say is the folowing script

# %%
import hello

print("This is from test_import.py")
# Out:
# This is from test_import.py

# %% [markdown]
# ### Test_import modified

# %%
import hello

print("This is from test_import.py")
hello.greet()  # Explicitly call greet() from the imported module
# Out:
# This is from test_import.py
# Hello from greet() in hello.py!

# %% [markdown]
# So now:
#
# The greet function is available when you import the module.
#
# It doesn’t run automatically (which is good behavior).
#
# You control when to call it from the other script.

# %% [markdown]
# ### Let's update greet() to accept a name as an argument and call it hello2.py the new file containing it
# ##### and modify test_import once again , say it test_import_modified2

# %%
import hello2

print("This is from test_import.py")
hello2.greet("Bob")  # Call greet with a different name
# Out:
# This is from test_import.py
# Hello, Bob!
